# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('00-puppy.jpg')
#opencv automaticly reads the img and converts it into a numpy arr

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img) #opencv reads the images in BGR format

# %%
imgRGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgRGB)

# %%
img_gray = cv2.imread('00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape #notice how there is now 3rd dimention cause its grayscale
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
imgRGB.shape
# Out:
# (1300, 1950, 3)

# %%
resizedImg = cv2.resize(imgRGB,(1000,400))

# %%
plt.imshow(resizedImg)

# %%
resizedwratioImg = cv2.resize(imgRGB,(0,0),imgRGB,0.5,0.5) #resized with 50% ratio

# %%
plt.imshow(resizedwratioImg)

# %%
resizedwratioImg.shape
# Out:
# (650, 975, 3)

# %%
flippedImg = cv2.flip(imgRGB,-1) #0 horizontal, 1 vertical, -1 both
plt.imshow(flippedImg)

# %%
type(imgRGB)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('copyOfCutePuppy.jpg',img) #opencv writes in rgb format
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8)) #we define a canvas space here
ax = fig.add_subplot(111) #1 plot subplot
ax.imshow(imgRGB) #now we can plot image larger
