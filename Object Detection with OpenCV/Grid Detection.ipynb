# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
flat_chess = cv2.imread("D:\\YEDEK\\Belgeler\\WS\\Python\\Computer Vision Course\Computer-Vision-with-Python\\Computer-Vision-with-Python\\DATA\\flat_chessboard.png")
plt.imshow(flat_chess)

# %%
#bool val if chess pattern found, corner coordinates   #dimention of the grid
found, corners = cv2.findChessboardCorners(flat_chess, (7, 7))

# %%
cv2.drawChessboardCorners(flat_chess, (7, 7), corners, found)
# Out:
# array([[[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        ...,
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots = cv2.imread("D:\\YEDEK\\Belgeler\\WS\\Python\\Computer Vision Course\Computer-Vision-with-Python\\Computer-Vision-with-Python\\DATA\\dot_grid.png")
plt.imshow(dots)

# %%
found, corners = cv2.findCirclesGrid(dots, (10, 10), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 29.5,  29.5]],
#
#        [[ 89.5,  29.5]],
#
#        [[149.5,  29.5]],
#
#        [[209.5,  29.5]],
#
#        [[269.5,  29.5]],
#
#        [[329.5,  29.5]],
#
#        [[389.5,  29.5]],
#
#        [[449.5,  29.5]],
#
#        [[509.5,  29.5]],
#
#        [[569.5,  29.5]],
#
#        [[ 29.5,  89.5]],
#
#        [[ 89.5,  89.5]],
#
#        [[149.5,  89.5]],
#
#        [[209.5,  89.5]],
#
#        [[269.5,  89.5]],
#
#        [[329.5,  89.5]],
#
#        [[389.5,  89.5]],
#
#        [[449.5,  89.5]],
#
#        [[509.5,  89.5]],
#
#        [[569.5,  89.5]],
#
#        [[ 29.5, 149.5]],
#
#        [[ 89.5, 149.5]],
#
#        [[149.5, 149.5]],
#
#        [[209.5, 149.5]],
#
#        [[269.5, 149.5]],
#
#        [[329.5, 149.5]],
#
#        [[389.5, 149.5]],
#
#        [[449.5, 149.5]],
#
#        [[509.5, 149.5]],
#
#        [[569.5, 149.5]],
#
#        [[ 29.5, 209.5]],
#
#        [[ 89.5, 209.5]],
#
#        [[149.5, 209.5]],
#
#        [[209.5, 209.5]],
#
# ...

# %%
plt.imshow(cv2.drawChessboardCorners(dots, (10, 10), corners, found))
